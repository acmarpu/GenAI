# %%
# run the current cell - shift + enter

# %%
# Tokenization with TikToken
# The cat sat on the mat  
# python -m pip install tiktoken

import tiktoken

encoder = tiktoken.encoding_for_model("gpt-4o")

text = "The cat sat on the mat"

tokens = encoder.encode(text)

print("Text:", text)

print("length of tokens", len(tokens))

for token_id in tokens:
    print(f"Token ID: {token_id}, Token: {encoder.decode([token_id])}")
# Out:
# Text: The cat sat on the mat
# length of tokens 6
# Token ID: 976, Token: The
# Token ID: 9059, Token:  cat
# Token ID: 10139, Token:  sat
# Token ID: 402, Token:  on
# Token ID: 290, Token:  the
# Token ID: 2450, Token:  mat

# %%
# API Request to OpenAI API 

import requests
import json

def ask_llm(prompt):
    response = requests.post("http://localhost:11434/api/chat", 
    json = {
        "model": "qwen3:1.7b",
        "messages": [
            {
                "role": "system", "content": "your are a helpful assistant"
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        "stream": False,
    }                         
    )

    result = response.json() ["message"] ["content"]
    return result

answer = ask_llm("who are you")
print("Answer from LLM:", answer)


def chat ():
    message = [
        {"role": "system", "content": "your are a bot"}
    ] 

    while True:
        user_input = input("you:")
        message.append({"role": "user", "content": user_input})
        response = requests.post("http://localhost:11434/api/chat",
        json = {
            "model": "qwen3:1.7b",
            "messages": message,
            "stream": False,
        }
        )
        result = response.json() ["message"] ["content"]
        print("bot:", result)
# Out:
# Answer from LLM: I am an AI assistant developed by Alibaba Cloud. I can help with a wide range of tasks, such as answering questions, providing information, solving problems, and offering advice. I can assist with language understanding, language generation, and other tasks. However, I cannot perform physical tasks or access the internet directly. Let me know how I can help!

# %%
#!pip install google-genai -q
#!python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\Users\marpu\AppData\Local\Programs\Python\Python314\Lib\site-packages (26.1.2)

# %%
import os

# Get the GEMINI_API_KEY from .env file
from dotenv import load_dotenv
from google import genai

load_dotenv()

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")
print("API Keys loaded")


client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])
print("Client Ready!")
# Out:
# API Keys loaded
# Client Ready!
